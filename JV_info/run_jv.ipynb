# %% [markdown]
# ### Notes
# Modify \omega_model\__init_.py
#
# (line 210) removed  _ at end of 'database_','v_cost_curves_', 'v_cost_clouds_'
#
# (line 221) added 2020 to cloud years log and removed 2050 from consumer iteration years
#
# want to extract vehicle_data variable, global - found in postproc_session
#
# Q: read the docs to figure out composite-translation

# %% [markdown]
# ### Run

# %%
# %cd C:/Users/johna/Documents/GitHub/EPA_OMEGA_Model/
# %cd C:/Users/johna/Downloads/2023-03-25-11-46-49-ld-central-compliance-run (1)/2023_03_25_11_46_49_ld_central_compliance_run/_Proposal/in
# !python omega_model/omega.py
# Out:
# C:\Users\johna\Documents\GitHub\EPA_OMEGA_Model
# importing omega_model/omega.py
# loading omega version 2.0.1
# importing C:\Users\johna\Documents\GitHub\EPA_OMEGA_Model\omega_model\common\omega_globals.py
# importing C:\Users\johna\Documents\GitHub\EPA_OMEGA_Model\omega_model\common\omega_types.py
# importing C:\Users\johna\Documents\GitHub\EPA_OMEGA_Model\omega_model\common\omega_db.py
# importing C:\Users\johna\Documents\GitHub\EPA_OMEGA_Model\omega_model\common\omega_log.py
# importing C:\Users\johna\Documents\GitHub\EPA_OMEGA_Model\omega_model\common\file_io.py
# importing C:\Users\johna\Documents\GitHub\EPA_OMEGA_Model\omega_model\common\input_validation.py
# importing C:\Users\johna\Documents\GitHub\EPA_OMEGA_Model\omega_model\omega.py
# importing C:\Users\johna\Documents\GitHub\EPA_OMEGA_Model\omega_model\context\onroad_fuels.py
# importing C:\Users\johna\Documents\GitHub\EPA_OMEGA_Model\omega_model\context\price_modifications.py
# ...
